# %%
import sys
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import pickle
import os

# %%
from keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
# Out:
# Using TensorFlow backend.

# %%
train_dir = "Fruits/Train"

# %%
batch_size = 50

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                  shear_range = 0.2,
                                  zoom_range = 0.2, 
                                  horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
training_data = train_datagen.flow_from_directory(train_dir,
                                                 batch_size=batch_size, 
                                                 target_size=(150,150),
                                                 class_mode = "categorical")
# Out:
# Found 70 images belonging to 4 classes.

# %%
import pandas as pd

training_df = pd.DataFrame(training_data.classes, columns=['classes'])

# %%
print(list(training_data.class_indices.keys()))
# Out:
# ['Banana', 'Leafy Vegetables', 'Onion', 'Potato']

# %%
TRAIN_DATA_DIR = 'Fruits/Train'

# %%
CATEGORIES = ['Banana', 'Leafy Vegetables', 'Onion', 'Potato']

# %%
for category in CATEGORIES:
    path = os.path.join(TRAIN_DATA_DIR, category)
    for img in os.listdir(path):
        img_array = load_img(os.path.join(path, img))
        plt.imshow(img_array)
        plt.show()
        break
    break

# %%
path
# Out:
# 'Fruits/Train\\Banana'

# %%
os.listdir(path)
# Out:
# ['Banana-Single - Copy (2).jpg',
#  'Banana-Single - Copy - Copy.jpg',
#  'Banana-Single - Copy.jpg',
#  'Banana-Single.jpg',
#  'CnMKOtOVUAAJiFm - Copy (2).jpg',
#  'CnMKOtOVUAAJiFm - Copy - Copy.jpg',
#  'CnMKOtOVUAAJiFm - Copy.jpg',
#  'CnMKOtOVUAAJiFm.jpg',
#  'GUEST_f5d0cfc3-9d02-4ee0-a6c6-ed5dc09971d1 - Copy (2).jpg',
#  'GUEST_f5d0cfc3-9d02-4ee0-a6c6-ed5dc09971d1 - Copy - Copy.jpg',
#  'GUEST_f5d0cfc3-9d02-4ee0-a6c6-ed5dc09971d1 - Copy.jpg',
#  'GUEST_f5d0cfc3-9d02-4ee0-a6c6-ed5dc09971d1.jpg',
#  'images (1) - Copy.jpg',
#  'images (1).jpg',
#  'images (2) - Copy.jpg',
#  'images (2).jpg',
#  'images (3) - Copy.jpg',
#  'images - Copy (2).jpg',
#  'images - Copy - Copy.jpg',
#  'images - Copy.jpg',
#  'images.jpg',
#  'Plantain-Yellow-PNG-Image - Copy (2).png',
#  'Plantain-Yellow-PNG-Image - Copy - Copy.png',
#  'Plantain-Yellow-PNG-Image - Copy.png',
#  'Plantain-Yellow-PNG-Image.png',
#  'PNGPIX-COM-Yellow-Banana-PNG-Transparent-Image - Copy (2).png',
#  'PNGPIX-COM-Yellow-Banana-PNG-Transparent-Image - Copy - Copy.png',
#  'PNGPIX-COM-Yellow-Banana-PNG-Transparent-Image - Copy.png',
#  'PNGPIX-COM-Yellow-Banana-PNG-Transparent-Image.png']

# %%
X = []
y = []

for features, label in training_data:
    X.append(features)
    y.append(label)

# %%
type(train_data)

# %%
import cv2
